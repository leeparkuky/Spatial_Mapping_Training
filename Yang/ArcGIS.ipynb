# %%
import geopandas as gpd
import pandas as pd
import arcgis 

from arcgis.gis import GIS,ContentManager 
from arcgis.mapping import WebMap, WebScene

# %%
app_id= "JL2Fgr5FI9bIJ7nI"

# %%
gis = GIS("https://ky-cancer.maps.arcgis.com", client_id=app_id)
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://ky-cancer.maps.arcgis.com/sharing/rest/oauth2/authorize?response_type=code&client_id=JL2Fgr5FI9bIJ7nI&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=4qqcHnAJbgcHsm1od3DsLV1ltuXKIv&allow_verification=false
# Enter code obtained on signing in using SAML: ········
# /Users/yangli/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ky-cancer.maps.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
contentManager= ContentManager(gis)

# %%
contentManager.search('')
# Out:
# [<Item title:"Hybrid County Basemap" type:Vector Tile Layer owner:todd.burus>,
#  <Item title:"Behavioral Risk Factors" type:Service Definition owner:lee.park>,
#  <Item title:"all_site_inc_map_cover_outlined" type:Image owner:todd.burus>,
#  <Item title:"sample" type:Application owner:adelineliyang>,
#  <Item title:"python" type:Application owner:adelineliyang>,
#  <Item title:"Basemap" type:Service Definition owner:todd.burus>,
#  <Item title:"Tract Basemap" type:Service Definition owner:todd.burus>,
#  <Item title:"Sociodemographics (Tract)" type:Feature Layer Collection owner:adelineliyang>,
#  <Item title:"Sociodemographics (County)" type:Shapefile owner:adelineliyang>,
#  <Item title:"Economic INdicators (Tract)" type:Shapefile owner:adelineliyang>]

# %%
#read in the tiger as pandas format and extract the shape formal
county = "https://www2.census.gov/geo/tiger/TIGER2019/COUNTY/tl_2019_us_county.zip"
gdf=gpd.read_file(county)

# %%
gdf
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD  \
# 0         31      039  00835841  31039     Cuming     Cuming County   06
# 1         53      069  01513275  53069  Wahkiakum  Wahkiakum County   06
# 2         35      011  00933054  35011    De Baca    De Baca County   06
# 3         31      109  00835876  31109  Lancaster  Lancaster County   06
# 4         31      129  00835886  31129   Nuckolls   Nuckolls County   06
# ...      ...      ...       ...    ...        ...               ...  ...
# 3228      13      123  00351260  13123     Gilmer     Gilmer County   06
# 3229      27      135  00659513  27135     Roseau     Roseau County   06
# 3230      28      089  00695768  28089    Madison    Madison County   06
# 3231      48      227  01383899  48227     Howard     Howard County   06
# 3232      54      099  01550056  54099      Wayne      Wayne County   06
#
#      CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 0         H1  G4020  None   None     None        A  1477652222  10690952
# 1         H1  G4020  None   None     None        A   680962890  61582307
# 2         H1  G4020  None   None     None        A  6016819475  29089486
# 3         H1  G4020   339  30700     None        A  2169270569  22849484
# 4         H1  G4020  None   None     None        A  1489645188   1718484
# ...      ...    ...   ...    ...      ...      ...         ...       ...
# 3228      H1  G4020  None   None     None        A  1103886891  12283371
# 3229      H1  G4020  None   None     None        A  4329471929  16913419
# 3230      H1  G4020   298  27140     None        A  1850602740  71274123
# 3231      H1  G4020  None  13700     None        A  2333039143   8841783
# 3232      H1  G4020   170  26580     None        A  1310550727  15814102
#
#          INTPTLAT      INTPTLON  \
# 0     +41.9158651  -096.7885168
# 1     +46.2946377  -123.4244583
# 2     +34.3592729  -104.3686961
# 3     +40.7835474  -096.6886584
# 4     +40.1764918  -098.0468422
# ...           ...           ...
# 3228  +34.6905055  -084.4546244
# 3229  +48.7610683  -095.8215042
# 3230  +32.6343703  -090.0341603
# 3231  +32.3034298  -101.4387208
# 3232  +38.1436416  -082.4226659
#
#                                                geometry
# 0     POLYGON ((-97.01952 42.00410, -97.01952 42.004...
# 1     POLYGON ((-123.43639 46.23820, -123.44759 46.2...
# 2     POLYGON ((-104.56739 33.99757, -104.56772 33.9...
# 3     POLYGON ((-96.91075 40.78494, -96.91075 40.790...
# 4     POLYGON ((-98.27367 40.08940, -98.27367 40.089...
# ...                                                 ...
# 3228  POLYGON ((-84.65478 34.66559, -84.65488 34.669...
# 3229  POLYGON ((-96.40466 48.80528, -96.40467 48.813...
# 3230  POLYGON ((-90.09363 32.70763, -90.09360 32.707...
# 3231  POLYGON ((-101.69227 32.27106, -101.69221 32.2...
# 3232  POLYGON ((-82.59529 38.36978, -82.59515 38.369...
#
# [3233 rows x 18 columns]

# %%
simple_gdf = gdf.loc[:, ["GEOID", "geometry"]]

# %%
import pickle 
d=pickle.load(open("../dataset.pickle","rb"))
df=d["cancer_incidence"]

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.head(3)
# Out:
# Site   FIPS           County          State       Type  All Site  Bladder  \
# 0     33001   Belknap County  New Hampshire  Incidence     519.3     26.6
# 1     33003   Carroll County  New Hampshire  Incidence     465.0     26.2
# 2     33005  Cheshire County  New Hampshire  Incidence     471.2     23.2
#
# Site  Brain & ONS  Cervix  Colon & Rectum  Corpus Uteri & Uterus, NOS  ...  \
# 0             6.4     NaN            41.9                        42.6  ...
# 1             8.3     NaN            35.7                        28.6  ...
# 2             6.3     NaN            37.7                        30.4  ...
#
# Site  Liver & IBD  Lung & Bronchus  Melanoma of the Skin  \
# 0             5.7             69.1                  40.3
# 1             5.4             57.6                  33.8
# 2             8.0             59.2                  40.4
#
# Site  Non-Hodgkin Lymphoma  Oral Cavity & Pharynx  Ovary  Pancreas  Prostate  \
# 0                     21.5                   14.6   13.1      15.3     121.4
# 1                     17.3                   13.5    9.0      12.4     127.1
# 2                     20.8                   10.0   10.7      13.2      95.6
#
# Site  Stomach  Thyroid
# 0         5.5     10.4
# 1         4.5      9.9
# 2         5.5      9.5
#
# [3 rows x 24 columns]

# %%
df.dtypes
simple_gdf.dtypes
# Out:
# GEOID         object
# geometry    geometry
# dtype: object

# %%
df.merge(simple_gdf, how= "left", left_on="FIPS", right_on="GEOID").drop("GEOID", axis=1)
# Out:
#      FIPS               County          State       Type  All Site  Bladder  \
# 0   33001       Belknap County  New Hampshire  Incidence     519.3     26.6
# 1   33003       Carroll County  New Hampshire  Incidence     465.0     26.2
# 2   33005      Cheshire County  New Hampshire  Incidence     471.2     23.2
# 3   33007          Coos County  New Hampshire  Incidence     484.3     28.5
# 4   33009       Grafton County  New Hampshire  Incidence     446.9     25.8
# 5   33011  Hillsborough County  New Hampshire  Incidence     461.2     26.2
# 6   33013     Merrimack County  New Hampshire  Incidence     484.7     29.0
# 7   33015    Rockingham County  New Hampshire  Incidence     495.3     29.0
# 8   33017     Strafford County  New Hampshire  Incidence     505.6     30.1
# 9   33019      Sullivan County  New Hampshire  Incidence     484.5     26.5
# 10  50001       Addison County        Vermont  Incidence     415.7     25.4
# 11  50003    Bennington County        Vermont  Incidence     482.7     22.0
# 12  50005     Caledonia County        Vermont  Incidence     433.2     23.9
# 13  50007    Chittenden County        Vermont  Incidence     448.6     21.1
# 14  50009         Essex County        Vermont  Incidence     463.0     36.6
# 15  50011      Franklin County        Vermont  Incidence     461.9     24.1
# 16  50013    Grand Isle County        Vermont  Incidence     522.3      NaN
# 17  50015      Lamoille County        Vermont  Incidence     457.6     22.1
# 18  50017        Orange County        Vermont  Incidence     460.9     20.5
# 19  50019       Orleans County        Vermont  Incidence     472.2     21.3
# 20  50021       Rutland County        Vermont  Incidence     477.9     27.1
# 21  50023    Washington County        Vermont  Incidence     455.2     25.6
# 22  50025       Windham County        Vermont  Incidence     445.4     22.9
# 23  50027       Windsor County        Vermont  Incidence     470.6     24.9
#
#     Brain & ONS  Cervix  Colon & Rectum  Corpus Uteri & Uterus, NOS  ...  \
# 0           6.4     NaN            41.9                        42.6  ...
# 1           8.3     NaN            35.7                        28.6  ...
# 2           6.3     NaN            37.7                        30.4  ...
# 3           NaN     NaN            39.7                        36.9  ...
# 4           7.8     NaN            34.7                        30.8  ...
# 5           6.8     5.7            33.6                        31.5  ...
# 6           8.3     NaN            33.5                        29.7  ...
# 7           8.5     4.7            38.0                        26.7  ...
# 8           6.6     7.5            39.9                        32.7  ...
# 9           8.7     NaN            36.4                        31.2  ...
# 10          NaN     NaN            31.1                        31.6  ...
# 11          NaN     NaN            35.0                        34.3  ...
# 12         10.0     NaN            38.8                        34.6  ...
# 13          7.1     4.8            30.4                        36.0  ...
# 14          NaN     NaN            32.6                         NaN  ...
# 15          NaN     NaN            35.5                        34.3  ...
# 16          NaN     NaN            41.2                         NaN  ...
# 17          NaN     NaN            36.2                        24.7  ...
# 18          9.2     NaN            35.0                        35.7  ...
# 19          NaN     NaN            45.1                        27.6  ...
# 20          4.6     NaN            34.6                        38.3  ...
# 21          4.6     NaN            32.3                        35.2  ...
# 22          7.8     NaN            39.2                        41.6  ...
# 23         10.7     NaN            37.7                        34.8  ...
#
#     Lung & Bronchus  Melanoma of the Skin  Non-Hodgkin Lymphoma  \
# 0              69.1                  40.3                  21.5
# 1              57.6                  33.8                  17.3
# 2              59.2                  40.4                  20.8
# 3              63.6                  28.6                  22.8
# 4              53.2                  41.5                  18.3
# 5              60.6                  26.4                  20.6
# 6              59.4                  36.4                  18.2
# 7              64.1                  31.4                  22.3
# 8              78.7                  27.2                  20.9
# 9              66.7                  37.5                  18.8
# 10             52.0                  28.7                  15.4
# 11             67.6                  40.6                  16.9
# 12             55.2                  34.6                  17.4
# 13             52.5                  39.3                  19.3
# 14             66.8                  41.7                   NaN
# 15             78.7                  33.2                  17.4
# 16             85.8                  57.8                   NaN
# 17             65.4                  51.4                  15.8
# 18             61.6                  45.9                  25.5
# 19             76.9                  31.8                  23.6
# 20             61.9                  35.9                  20.9
# 21             61.2                  36.7                  18.2
# 22             49.8                  34.0                  21.2
# 23             59.4                  42.2                  17.8
#
#     Oral Cavity & Pharynx  Ovary  Pancreas  Prostate  Stomach  Thyroid  \
# 0                    14.6   13.1      15.3     121.4      5.5     10.4
# 1                    13.5    9.0      12.4     127.1      4.5      9.9
# 2                    10.0   10.7      13.2      95.6      5.5      9.5
# 3                    14.5   14.6      14.9      93.8      7.0     11.8
# 4                    11.8    8.5      10.6      87.0      5.3     12.0
# 5                    11.1   10.3      11.9     110.6      6.0     15.6
# 6                    13.1    9.3      11.9     111.3      4.9     16.0
# 7                    12.4   10.7      13.7     115.5      4.6     16.5
# 8                    11.6    8.3      12.2     101.8      4.1     17.6
# 9                     8.9    9.6      14.2      92.1      8.3     16.8
# 10                    5.7    NaN      11.0     116.2      NaN     14.7
# 11                   11.0   15.2      12.5      96.7      7.1     23.8
# 12                   14.7    NaN      12.5      66.8      NaN     11.5
# 13                   12.3    7.6      13.9      91.9      4.1     14.0
# 14                    NaN    NaN       NaN      75.7      NaN      NaN
# 15                   12.9    NaN       8.7      96.1      NaN     18.2
# 16                    NaN    NaN       NaN      89.1      NaN      NaN
# 17                    NaN    NaN       NaN      97.1      NaN     13.7
# 18                   12.0    NaN       9.6      99.9      NaN     16.6
# 19                    8.8    NaN      11.7      85.1      NaN      NaN
# 20                   15.5    8.3      10.7      91.7      7.2     17.5
# 21                   13.2   13.5      12.3      97.0      6.0     11.9
# 22                   13.3   15.7      12.6      81.6      5.5      9.2
# 23                   13.0    7.7      12.0      89.6      3.8     13.7
#
#                                              geometry
# 0   POLYGON ((-71.70635 43.53762, -71.70691 43.538...
# 1   POLYGON ((-71.32357 44.09161, -71.32294 44.091...
# 2   POLYGON ((-72.45946 43.02062, -72.45949 43.020...
# 3   POLYGON ((-71.60203 44.77087, -71.60200 44.771...
# 4   POLYGON ((-72.03982 44.15573, -72.03974 44.155...
# 5   POLYGON ((-72.00347 42.93022, -72.00364 42.931...
# 6   POLYGON ((-72.04974 43.38026, -72.04968 43.381...
# 7   POLYGON ((-71.01257 43.08199, -71.01231 43.082...
# 8   POLYGON ((-71.15936 43.35512, -71.15952 43.355...
# 9   POLYGON ((-72.40649 43.33755, -72.40634 43.337...
# 10  POLYGON ((-73.41393 44.10784, -73.41344 44.108...
# 11  POLYGON ((-73.25916 43.21685, -73.25880 43.227...
# 12  MULTIPOLYGON (((-72.08886 44.68371, -72.09305 ...
# 13  POLYGON ((-73.25446 44.60790, -73.25456 44.608...
# 14  POLYGON ((-71.91774 44.94363, -71.91746 44.944...
# 15  POLYGON ((-73.19402 44.88684, -73.19327 44.888...
# 16  POLYGON ((-73.34274 44.91372, -73.34111 44.914...
# 17  POLYGON ((-72.79550 44.69220, -72.79479 44.695...
# 18  POLYGON ((-72.44303 44.12867, -72.44202 44.132...
# 19  POLYGON ((-72.24674 45.00464, -72.23941 45.004...
# 20  POLYGON ((-73.30208 43.62384, -73.30208 43.624...
# 21  POLYGON ((-72.65440 44.39822, -72.64243 44.415...
# 22  POLYGON ((-72.86874 43.11317, -72.86803 43.125...
# 23  POLYGON ((-72.70094 43.68283, -72.71514 43.686...
#
# [24 rows x 25 columns]

# %%
temp=df.merge(simple_gdf, how='left', left_on='FIPS', right_on='GEOID').drop("GEOID", axis=1)
temp
# Out:
#      FIPS               County          State       Type  All Site  Bladder  \
# 0   33001       Belknap County  New Hampshire  Incidence     519.3     26.6
# 1   33003       Carroll County  New Hampshire  Incidence     465.0     26.2
# 2   33005      Cheshire County  New Hampshire  Incidence     471.2     23.2
# 3   33007          Coos County  New Hampshire  Incidence     484.3     28.5
# 4   33009       Grafton County  New Hampshire  Incidence     446.9     25.8
# 5   33011  Hillsborough County  New Hampshire  Incidence     461.2     26.2
# 6   33013     Merrimack County  New Hampshire  Incidence     484.7     29.0
# 7   33015    Rockingham County  New Hampshire  Incidence     495.3     29.0
# 8   33017     Strafford County  New Hampshire  Incidence     505.6     30.1
# 9   33019      Sullivan County  New Hampshire  Incidence     484.5     26.5
# 10  50001       Addison County        Vermont  Incidence     415.7     25.4
# 11  50003    Bennington County        Vermont  Incidence     482.7     22.0
# 12  50005     Caledonia County        Vermont  Incidence     433.2     23.9
# 13  50007    Chittenden County        Vermont  Incidence     448.6     21.1
# 14  50009         Essex County        Vermont  Incidence     463.0     36.6
# 15  50011      Franklin County        Vermont  Incidence     461.9     24.1
# 16  50013    Grand Isle County        Vermont  Incidence     522.3      NaN
# 17  50015      Lamoille County        Vermont  Incidence     457.6     22.1
# 18  50017        Orange County        Vermont  Incidence     460.9     20.5
# 19  50019       Orleans County        Vermont  Incidence     472.2     21.3
# 20  50021       Rutland County        Vermont  Incidence     477.9     27.1
# 21  50023    Washington County        Vermont  Incidence     455.2     25.6
# 22  50025       Windham County        Vermont  Incidence     445.4     22.9
# 23  50027       Windsor County        Vermont  Incidence     470.6     24.9
#
#     Brain & ONS  Cervix  Colon & Rectum  Corpus Uteri & Uterus, NOS  ...  \
# 0           6.4     NaN            41.9                        42.6  ...
# 1           8.3     NaN            35.7                        28.6  ...
# 2           6.3     NaN            37.7                        30.4  ...
# 3           NaN     NaN            39.7                        36.9  ...
# 4           7.8     NaN            34.7                        30.8  ...
# 5           6.8     5.7            33.6                        31.5  ...
# 6           8.3     NaN            33.5                        29.7  ...
# 7           8.5     4.7            38.0                        26.7  ...
# 8           6.6     7.5            39.9                        32.7  ...
# 9           8.7     NaN            36.4                        31.2  ...
# 10          NaN     NaN            31.1                        31.6  ...
# 11          NaN     NaN            35.0                        34.3  ...
# 12         10.0     NaN            38.8                        34.6  ...
# 13          7.1     4.8            30.4                        36.0  ...
# 14          NaN     NaN            32.6                         NaN  ...
# 15          NaN     NaN            35.5                        34.3  ...
# 16          NaN     NaN            41.2                         NaN  ...
# 17          NaN     NaN            36.2                        24.7  ...
# 18          9.2     NaN            35.0                        35.7  ...
# 19          NaN     NaN            45.1                        27.6  ...
# 20          4.6     NaN            34.6                        38.3  ...
# 21          4.6     NaN            32.3                        35.2  ...
# 22          7.8     NaN            39.2                        41.6  ...
# 23         10.7     NaN            37.7                        34.8  ...
#
#     Lung & Bronchus  Melanoma of the Skin  Non-Hodgkin Lymphoma  \
# 0              69.1                  40.3                  21.5
# 1              57.6                  33.8                  17.3
# 2              59.2                  40.4                  20.8
# 3              63.6                  28.6                  22.8
# 4              53.2                  41.5                  18.3
# 5              60.6                  26.4                  20.6
# 6              59.4                  36.4                  18.2
# 7              64.1                  31.4                  22.3
# 8              78.7                  27.2                  20.9
# 9              66.7                  37.5                  18.8
# 10             52.0                  28.7                  15.4
# 11             67.6                  40.6                  16.9
# 12             55.2                  34.6                  17.4
# 13             52.5                  39.3                  19.3
# 14             66.8                  41.7                   NaN
# 15             78.7                  33.2                  17.4
# 16             85.8                  57.8                   NaN
# 17             65.4                  51.4                  15.8
# 18             61.6                  45.9                  25.5
# 19             76.9                  31.8                  23.6
# 20             61.9                  35.9                  20.9
# 21             61.2                  36.7                  18.2
# 22             49.8                  34.0                  21.2
# 23             59.4                  42.2                  17.8
#
#     Oral Cavity & Pharynx  Ovary  Pancreas  Prostate  Stomach  Thyroid  \
# 0                    14.6   13.1      15.3     121.4      5.5     10.4
# 1                    13.5    9.0      12.4     127.1      4.5      9.9
# 2                    10.0   10.7      13.2      95.6      5.5      9.5
# 3                    14.5   14.6      14.9      93.8      7.0     11.8
# 4                    11.8    8.5      10.6      87.0      5.3     12.0
# 5                    11.1   10.3      11.9     110.6      6.0     15.6
# 6                    13.1    9.3      11.9     111.3      4.9     16.0
# 7                    12.4   10.7      13.7     115.5      4.6     16.5
# 8                    11.6    8.3      12.2     101.8      4.1     17.6
# 9                     8.9    9.6      14.2      92.1      8.3     16.8
# 10                    5.7    NaN      11.0     116.2      NaN     14.7
# 11                   11.0   15.2      12.5      96.7      7.1     23.8
# 12                   14.7    NaN      12.5      66.8      NaN     11.5
# 13                   12.3    7.6      13.9      91.9      4.1     14.0
# 14                    NaN    NaN       NaN      75.7      NaN      NaN
# 15                   12.9    NaN       8.7      96.1      NaN     18.2
# 16                    NaN    NaN       NaN      89.1      NaN      NaN
# 17                    NaN    NaN       NaN      97.1      NaN     13.7
# 18                   12.0    NaN       9.6      99.9      NaN     16.6
# 19                    8.8    NaN      11.7      85.1      NaN      NaN
# 20                   15.5    8.3      10.7      91.7      7.2     17.5
# 21                   13.2   13.5      12.3      97.0      6.0     11.9
# 22                   13.3   15.7      12.6      81.6      5.5      9.2
# 23                   13.0    7.7      12.0      89.6      3.8     13.7
#
#                                              geometry
# 0   POLYGON ((-71.70635 43.53762, -71.70691 43.538...
# 1   POLYGON ((-71.32357 44.09161, -71.32294 44.091...
# 2   POLYGON ((-72.45946 43.02062, -72.45949 43.020...
# 3   POLYGON ((-71.60203 44.77087, -71.60200 44.771...
# 4   POLYGON ((-72.03982 44.15573, -72.03974 44.155...
# 5   POLYGON ((-72.00347 42.93022, -72.00364 42.931...
# 6   POLYGON ((-72.04974 43.38026, -72.04968 43.381...
# 7   POLYGON ((-71.01257 43.08199, -71.01231 43.082...
# 8   POLYGON ((-71.15936 43.35512, -71.15952 43.355...
# 9   POLYGON ((-72.40649 43.33755, -72.40634 43.337...
# 10  POLYGON ((-73.41393 44.10784, -73.41344 44.108...
# 11  POLYGON ((-73.25916 43.21685, -73.25880 43.227...
# 12  MULTIPOLYGON (((-72.08886 44.68371, -72.09305 ...
# 13  POLYGON ((-73.25446 44.60790, -73.25456 44.608...
# 14  POLYGON ((-71.91774 44.94363, -71.91746 44.944...
# 15  POLYGON ((-73.19402 44.88684, -73.19327 44.888...
# 16  POLYGON ((-73.34274 44.91372, -73.34111 44.914...
# 17  POLYGON ((-72.79550 44.69220, -72.79479 44.695...
# 18  POLYGON ((-72.44303 44.12867, -72.44202 44.132...
# 19  POLYGON ((-72.24674 45.00464, -72.23941 45.004...
# 20  POLYGON ((-73.30208 43.62384, -73.30208 43.624...
# 21  POLYGON ((-72.65440 44.39822, -72.64243 44.415...
# 22  POLYGON ((-72.86874 43.11317, -72.86803 43.125...
# 23  POLYGON ((-72.70094 43.68283, -72.71514 43.686...
#
# [24 rows x 25 columns]

# %%
sdf= pd.DataFrame.spatial.from_geodataframe(temp, column_name="geometry")
# Out:
# Error acquiring spatial reference from GeoDataFrame Spatial reference will not be set.'DataFrame' object has no attribute 'crs'

# %%
lyrs= contentManager.import_data(sdf, title="First Sample", folder= "sample")

# %%
lyrs
# Out:
# <Item title:"First Sample" type:Feature Layer Collection owner:adelineliyang>

# %%
https://developers.arcgis.com/python/
# Out:
#   Input In [24]
#     https://developers.arcgis.com/python/
#           ^
# SyntaxError: invalid syntax
